# %%
# %matplotlib inline
from __future__ import division

import pandas as pd
import utils

# %%
visitors, events, devices, url_categories = utils.load_data(event_categories=True)
# Out:
# /usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2821: DtypeWarning: Columns (5,6,7,8,11,12,13,14,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# /usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2821: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
categorized_visits = pd.merge(visitors, events, on='dg_id')
categorized_visits['authorized'] = categorized_visits.identity_type.apply(lambda x: 1 if x=='AUT' else 0)

# %%
pharma = categorized_visits[categorized_visits.site_category=='Pharma']
pharma_activity = pharma.groupby('category_url').authorized.agg(['sum', 'count']).reset_index()
pharma_activity.columns = ['url', 'authorized_visits', 'total_visits']
pharma_activity = pd.merge(url_categories, pharma_activity, on='url').fillna('')
pharma_activity['pct_authorized'] = pharma_activity.apply(lambda x: x.authorized_visits/x.total_visits, axis=1)

# %%
def authorized_visits_print(pharma_site, pharma_activity):
    f = pharma_activity[pharma_activity.url==pharma_site]
    print 'Pharma Site :: ' + pharma_site + ' :: ' + str(round(f.pct_authorized*100,2)) + '% authorized'
    disease_category = f.disease_category.item()
    fd = pharma_activity[pharma_activity.disease_category==disease_category]
    if len(fd) >= 3:
        authorized = sum(fd.authorized_visits)
        total = sum(fd.total_visits)
        print 'Disease Category :: ' + disease_category + ' :: ' + str(round(authorized/total*100, 2)) + '% authorized'
        diseases = [x.lower().strip() for x in f.disease.item().split(',') if x.strip() != '']
        for d in diseases:
            authorized = 0
            total = 0
            count = 0
            for row in fd.iterrows():
                r = row[1]
                if d in r.disease.lower():
                    authorized += r.authorized_visits
                    total += r.total_visits
                    count += 1
            if count >= 3:
                print 'Disease :: ' + d + ' :: ' + str(round(authorized/total*100, 2)) + '% authorized'

# %%
pharma_activity['pharma_id'] = range(len(pharma_activity))

# %%
def authorized_visits_dict(pharma_site, pharma_activity):
    compare = []
    f = pharma_activity[pharma_activity.url==pharma_site]
    d = {}
    d['pharma_id'] = f.pharma_id.item()
    d['level'] = 'main pharma site'
    d['name'] = pharma_site
    d['pct_authorized'] = round(f.pct_authorized*100,2)
    compare.append(d)
    disease_category = f.disease_category.item()
    fd = pharma_activity[pharma_activity.disease_category==disease_category]
    if len(fd) >= 3:
        d = {}
        authorized = sum(fd.authorized_visits)
        total = sum(fd.total_visits)
        d['pharma_id'] = f.pharma_id.item()
        d['level'] = 'disease category'
        d['name'] = disease_category 
        d['pct_authorized'] = round(authorized/total*100, 2)
        d['number_of_sites'] = len(fd)  
        compare.append(d)
        diseases = [x.lower().strip() for x in f.disease.item().split(',') if x.strip() != '']
        for t in diseases:
            authorized = 0
            total = 0
            count = 0
            for row in pharma_activity.iterrows():
                r = row[1]
                if t in r.disease.lower():
                    authorized += r.authorized_visits
                    total += r.total_visits
                    count += 1
            if count >= 3:
                d = {}
                d['pharma_id'] = f.pharma_id.item()
                d['level'] = 'disease'
                d['name'] = t
                d['pct_authorized'] = round(authorized/total*100, 2)
                d['number_of_sites'] = count
                compare.append(d)
    return compare

# %%
authorized_visits_dict(url, pharma_activity)
# Out:
# [{'level': 'main pharma site',
#   'name': 'www.zostavax.com',
#   'pct_authorized': 68.76,
#   'pharma_id': 114},
#  {'level': 'disease category',
#   'name': 'Infectious Disease',
#   'number_of_sites': 10,
#   'pct_authorized': 76.01,
#   'pharma_id': 114}]

# %%
all_urls = []
for url in pharma_activity.url:
    all_urls += authorized_visits_dict(url, pharma_activity)

# %%
df = pd.DataFrame(all_urls)

# %%
df.to_csv('authorized_visits_by_disease.csv')

# %%
unk = pd.read_csv('../data/unqualified_traffic_summary.csv')

# %%
unk.head()
# Out:
#           date                                             domain  sessions  \
# 0  ﻿2017-02-01                                                NaN         5
# 1   2017-02-01  0-press.endocrine.org.elibrary.qatar-weill.cor...         1
# 2   2017-02-01                   0-press.endocrine.org.fama.us.es         1
# 3   2017-02-01             0-press.endocrine.org.libus.csd.mu.edu         1
# 4   2017-02-01                                         10.60.2.43         1
#
#    unique_urls  pageviews unqualified
# 0            5          5           Y
# 1            1          2           Y
# 2            2          2           N
# 3            1          1           N
# 4            9          9           N

# %%
unk.unqualified.value_counts()
# Out:
# N    49787
# Y     3733
# Name: unqualified, dtype: int64

# %%
unk.sample(10)
# Out:
#              date                                             domain  \
# 7282   2017-02-22                  press.endocrine.org.pbidi.unam.mx
# 29947  2017-05-04                           www.clinicaloncology.com
# 19184  2017-03-27  theoncologist.alphamedpress.org.proxy.lib.umic...
# 30221  2017-05-05                       www.knowyourprostateplan.com
# 31311  2017-05-10                             ophth.broadcastmed.com
# 41079  2017-06-14                                            flip.it
# 20829  2017-04-01                    theoncologist.alphamedpress.org
# 37840  2017-06-02                       www.healthjobsnationwide.com
# 40415  2017-06-12                             endonews.matrixdev.net
# 47699  2017-07-07                        endocrinenews.endocrine.org
#
#        sessions  unique_urls  pageviews unqualified
# 7282          2            2          2           N
# 29947       140           74        308           N
# 19184         1            1          2           N
# 30221       130          120        390           N
# 31311         8            7         13           N
# 41079         2            2          2           N
# 20829      4632         2278       6760           N
# 37840      2342         7216      11201           N
# 40415         1            1          1           Y
# 47699       667          148       1066           N

# %%
unk['stripped_url'] = unk.domain.apply(lambda x: utils.clean_url(x, strip=True))

# %%
unk_overall = unk.groupby('stripped_url').sum().reset_index()
unk_overall.columns = ['stripped_url', 'unk_sesions', 'unk_unique_urls', 'unk_pageviews']

# %%
unk_overall.head()
# Out:
#       stripped_url  unk_sesions  unk_unique_urls  unk_pageviews
# 0                0            3                5             19
# 1      0-endocrine            4                6             15
# 2       0-journals            1                1              1
# 3          0-press          252              259            371
# 4  0-theoncologist            2                7             10

# %%
url_categories = pd.merge(url_categories, unk_overall, on='stripped_url', how='left')

# %%
unk[unk.domain.str.contains('hcp')]
# Out:
#              date                                       domain  sessions  \
# 68     2017-02-01                            hcp.cabometyx.com       110
# 350    2017-02-01                         www.myrbetriqhcp.com        68
# 379    2017-02-01                          www.vesicarehcp.com        25
# 53440  2017-07-25                           www.linzesshcp.com       531
# 53463  2017-07-25                 www.opdivoinformationhcp.com        28
# 53487  2017-07-25                 www.rituxanforgpampa-hcp.com        43
# 53489  2017-07-25                     www.rituxanforra-hcp.com       144
# 53499  2017-07-25                          www.sprycel-hcp.com        57
# 53513  2017-07-25                         www.venclextahcp.com       226
#
#        unique_urls  pageviews unqualified              stripped_url
# 68              37        186           N                   hcp/hcp
# 350              7         81           N              myrbetriqhcp
# 379              5         28           N               vesicarehcp
# 388            343        875           N                 xtandihcp
# 393             34         48           N                 xtandihcp
# 455            175        338           N                   hcp/hcp
# 739              9         95           N              myrbetriqhcp
# 772              6         49           N               vesicarehcp
# 779            274        871           N                 xtandihcp
# 782             40        104           N                 xtandihcp
# 844            227        475           N                   hcp/hcp
# 1094            11         73           N              myrbetriqhcp
# 1130             9         27           N               vesicarehcp
# 1135           273        869           N                 xtandihcp
# 1141            31         44           N                 xtandihcp
# 1178           143        246           N                   hcp/hcp
# 1368            10         55           N              myrbetriqhcp
# 1396             6         14           N               vesicarehcp
# 1403           180        369           N                 xtandihcp
# 1406            20         21           N                 xtandihcp
# 1441           132        234           N                   hcp/hcp
# 1643             9         28           N              myrbetriqhcp
# 1675             4          9           N               vesicarehcp
# 1680           158        257           N                 xtandihcp
# 1683            16         23           N                 xtandihcp
# 1742           244        444           N                   hcp/hcp
# 2005            11        105           N              myrbetriqhcp
# 2040            12         50           N               vesicarehcp
# 2047           276        665           N                 xtandihcp
# 2050            35         59           N                 xtandihcp
# ...            ...        ...         ...                       ...
# 52716           53        282           N         immunooncologyhcp
# 52729           38        535           N                linzesshcp
# 52748           11         31           N      opdivoinformationhcp
# 52769           10         27           N  rituxanforgpampa-hcp/hcp
# 52771            9         60           N      rituxanforra-hcp/hcp
# 52779           20         40           N           sprycel-hcp/hcp
# 52791           95        173           N              venclextahcp
# 52861           77        430           N                   hcp/hcp
# 53004          111       3946           N                actemrahcp
# 53012           32        283           N           avastin-hcp/hcp
# 53048           49        312           N                   hcp/hcp
# 53055           72        605           N         immunooncologyhcp
# 53068           47        815           N                linzesshcp
# 53089           26        135           N      opdivoinformationhcp
# 53112           10         57           N  rituxanforgpampa-hcp/hcp
# 53114           18        159           N      rituxanforra-hcp/hcp
# 53123           30         97           N           sprycel-hcp/hcp
# 53137          150        316           N              venclextahcp
# 53200          130        517           N                   hcp/hcp
# 53371          119        862           N                actemrahcp
# 53379           41        312           N           avastin-hcp/hcp
# 53420            1          1           N                   hcp/hcp
# 53421           53        405           N                   hcp/hcp
# 53427           91        523           N         immunooncologyhcp
# 53440           45        829           N                linzesshcp
# 53463           16         46           N      opdivoinformationhcp
# 53487           17        261           N  rituxanforgpampa-hcp/hcp
# 53489           22        273           N      rituxanforra-hcp/hcp
# 53499           20        287           N           sprycel-hcp/hcp
# 53513          174        342           N              venclextahcp
#
# [876 rows x 7 columns]
