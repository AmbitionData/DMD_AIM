# %%
import pandas as pd

# %%
# look at updated mappings
url_categories = pd.read_csv('../data/url_categories_updated_8_11.csv')

# %%
url_categories = url_categories[url_categories.columns[:-1]]
url_categories = url_categories.dropna(subset=['Site'])

# %%
url_categories.columns = ['dt_first_view', 'url', 'site_category', 'site_sub_category', 'disease_category', 'disease', 'sub_disease']

# %%
url_categories.head()
# Out:
#   dt_first_view                                                url  \
# 0      04/13/17  http://www.paradigmspine.com/content/are-you-a...
# 1      04/13/17  http://www.paradigmspine.com/content/back-spin...
# 2      04/13/17  http://www.paradigmspine.com/content/coflex-study
# 3      04/13/17  http://www.paradigmspine.com/content/degenerat...
# 4      04/13/17  http://www.paradigmspine.com/content/degenerat...
#
#   site_category site_sub_category disease_category disease sub_disease
# 0    Med Device  Branded Consumer          Surgery     NaN         NaN
# 1    Med Device  Branded Consumer          Surgery     NaN         NaN
# 2    Med Device  Branded Consumer          Surgery     NaN         NaN
# 3    Med Device  Branded Consumer          Surgery     NaN         NaN
# 4    Med Device  Branded Consumer          Surgery     NaN         NaN

# %%
# merge with existing mappings

old_urls = pd.read_csv('../data/disease_mapping_cbg_newURLs.csv')

# %%
old_urls.head()
# Out:
#                                                 Site Site Category  \
# 0  http://www.paradigmspine.com/content/are-you-a...    Med Device
# 1  http://www.paradigmspine.com/content/back-spin...    Med Device
# 2  http://www.paradigmspine.com/content/coflex-study    Med Device
# 3  http://www.paradigmspine.com/content/degenerat...    Med Device
# 4  http://www.paradigmspine.com/content/degenerat...    Med Device
#
#   Site Sub Category Disease Category\r(Acceptabl Values)  Disease  \
# 0  Branded Consumer                               Surgery     NaN
# 1  Branded Consumer                               Surgery     NaN
# 2  Branded Consumer                               Surgery     NaN
# 3  Branded Consumer                               Surgery     NaN
# 4  Branded Consumer                               Surgery     NaN
#
#       Pharma firm
# 0  Paradigm Spine
# 1  Paradigm Spine
# 2  Paradigm Spine
# 3  Paradigm Spine
# 4  Paradigm Spine

# %%
old_urls.columns = ['url', 'site_category', 'site_sub_category', 'disease_category', 'disease', 'pharma_firm']
old_urls = old_urls.dropna(subset=['url'])

# %%
new_urls = pd.merge(url_categories, old_urls[['url', 'pharma_firm']], on='url', how='left', suffixes=['1', '2'])

# %%
new_urls.head()
# hm slight mismatch need to look into this
# Out:
#   dt_first_view                                                url  \
# 0      04/13/17  http://www.paradigmspine.com/content/are-you-a...
# 1      04/13/17  http://www.paradigmspine.com/content/back-spin...
# 2      04/13/17  http://www.paradigmspine.com/content/coflex-study
# 3      04/13/17  http://www.paradigmspine.com/content/degenerat...
# 4      04/13/17  http://www.paradigmspine.com/content/degenerat...
#
#   site_category site_sub_category disease_category disease sub_disease  \
# 0    Med Device  Branded Consumer          Surgery     NaN         NaN
# 1    Med Device  Branded Consumer          Surgery     NaN         NaN
# 2    Med Device  Branded Consumer          Surgery     NaN         NaN
# 3    Med Device  Branded Consumer          Surgery     NaN         NaN
# 4    Med Device  Branded Consumer          Surgery     NaN         NaN
#
#       pharma_firm
# 0  Paradigm Spine
# 1  Paradigm Spine
# 2  Paradigm Spine
# 3  Paradigm Spine
# 4  Paradigm Spine

# %%
new_urls.to_csv('../data/url_categories_merged_20170814.csv', index=False)

# %%
urls = pd.read_csv('../data/url_categories_merged_20170814.csv')

# %%
urls
# Out:
#     dt_first_view                                                url  \
# 0        04/13/17  http://www.paradigmspine.com/content/are-you-a...
# 1        04/13/17  http://www.paradigmspine.com/content/back-spin...
# 2        04/13/17  http://www.paradigmspine.com/content/coflex-study
# 3        04/13/17  http://www.paradigmspine.com/content/degenerat...
# 4        04/13/17  http://www.paradigmspine.com/content/degenerat...
# 5        04/13/17      http://www.paradigmspine.com/content/glossary
# 6        04/13/17  http://www.paradigmspine.com/content/patients-...
# 7        04/13/17  http://www.paradigmspine.com/content/patient-t...
# 8        04/13/17  http://www.paradigmspine.com/content/spinal-st...
# 9        04/13/17  http://www.paradigmspine.com/content/spondylol...
# 10       04/13/17  http://www.paradigmspine.com/content/spondylol...
# 11       04/13/17       http://www.paradigmspine.com/surgeon-locator
# 12       04/13/17                              www.paradigmspine.com
# 13       12/21/15                                  endocrinenews.org
# 14       04/05/16                                press.endocrine.org
# 15       04/18/16                             sessions.endocrine.org
# 16       05/17/17                                       musc.bcst.md
# 17       05/17/17                                  www.endosuite.com
# 18       08/11/16                          www.thedoctorschannel.com
# 19       11/11/16                               www.broadcastmed.com
# 20       11/11/16             Clinicalconnection.hopkinsmedicine.org
# 21       11/11/16                           Learning.uchospitals.edu
# 22       11/11/16                       Medprofvideos.mayoclinic.org
# 23       11/11/16                                       Uhdoctor.org
# 24       01/11/17                                     www.naccme.com
# 25       02/07/17                             www.physicians.umm.edu
# 26       05/17/17                     professionals.barnesjewish.org
# 27       05/17/17                         videolink.pennmedicine.org
# 28       05/17/17                          medchannel.wakehealth.edu
# 29       05/17/17                   www.educationchannel.stryker.com
# ..            ...                                                ...
# 226      01/11/17                  www.journalofclinicalpathways.com
# 227           NaN                                           JMIR.org
# 228           NaN                                www.doctorunite.com
# 229      05/04/16                              www.theoncologist.com
# 230      07/05/17         https://www.healio.com/hematology-oncology
# 231      redirect                             www.oncology-times.com
# 232      03/17/16                           www.clinicaloncology.com
# 233      07/19/16                                 www.wkoncology.com
# 234      05/03/17                           www.painmedicinenews.com
# 235      01/16/17                              www.podiatrytoday.com
# 236      01/16/17                     www.podiatrytoday.com/advance/
# 237      01/11/17                             psychcongress.com/home
# 238      05/10/17                         www.generalsurgerynews.com
# 239      09/08/16                              www.nursingcenter.com
# 240      01/11/17                                           sawc.net
# 241      01/16/17                             www.woundsresearch.com
# 242      01/16/17                          www.todayswoundclinic.com
# 243      04/19/17                                       www.o-wm.com
# 244      05/03/17                       www.pharmacypracticenews.com
# 245      05/10/17                 www.specialtypharmacycontinuum.com
# 246      03/18/16                       www.healthjobsnationwide.com
# 247      03/24/16                             www.deltaplacement.com
# 248      03/25/16                                www.deltalocums.com
# 249      03/25/16                   www.deltahealthcareproviders.com
# 250      05/15/17                                 www.healthjobs.com
# 251      05/15/17                    www.pharmadiversityjobboard.com
# 252      07/13/17                                      www.nchcr.com
# 253           NaN            http://www.goldfishmedicalstaffing.com/
# 254      09/22/16                                      globalrph.com
# 255      09/22/16                                    m.globalrph.com
#
#            site_category site_sub_category  \
# 0             Med Device  Branded Consumer
# 1             Med Device  Branded Consumer
# 2             Med Device  Branded Consumer
# 3             Med Device  Branded Consumer
# 4             Med Device  Branded Consumer
# 5             Med Device  Branded Consumer
# 6             Med Device  Branded Consumer
# 7             Med Device  Branded Consumer
# 8             Med Device  Branded Consumer
# 9             Med Device  Branded Consumer
# 10            Med Device  Branded Consumer
# 11            Med Device  Branded Consumer
# 12            Med Device      Branded HCP
# 13   Medical Association       Multi Topic
# 14   Medical Association     Single Topic
# 15   Medical Association       Multi Topic
# 16     Medical Education       Multi Topic
# 17     Medical Education     Single Topic
# 18     Medical Education       Multi Topic
# 19     Medical Education       Multi Topic
# 20     Medical Education       Multi Topic
# 21     Medical Education       Multi Topic
# 22     Medical Education       Multi Topic
# 23     Medical Education       Multi Topic
# 24     Medical Education       Multi Topic
# 25     Medical Education       Multi Topic
# 26     Medical Education       Multi Topic
# 27     Medical Education       Multi Topic
# 28     Medical Education       Multi Topic
# 29     Medical Education       Multi Topic
# ..                   ...               ...
# 226            Publisher       Multi Topic
# 227            Publisher       Multi Topic
# 228            Publisher       Multi Topic
# 229            Publisher     Single Topic
# 230            Publisher     Single Topic
# 231            Publisher     Single Topic
# 232            Publisher     Single Topic
# 233            Publisher     Single Topic
# 234            Publisher     Single Topic
# 235            Publisher     Single Topic
# 236            Publisher     Single Topic
# 237            Publisher     Single Topic
# 238            Publisher     Single Topic
# 239            Publisher     Single Topic
# 240            Publisher     Single Topic
# 241            Publisher     Single Topic
# 242            Publisher     Single Topic
# 243            Publisher     Single Topic
# 244            Publisher     Single Topic
# 245            Publisher     Single Topic
# 246            Recruiter       Multi Topic
# 247            Recruiter       Multi Topic
# 248            Recruiter       Multi Topic
# 249            Recruiter       Multi Topic
# 250            Recruiter       Multi Topic
# 251            Recruiter       Multi Topic
# 252            Recruiter       Multi Topic
# 253            Recruiter       Multi Topic
# 254       Reference Tool       Multi Topic
# 255       Reference Tool       Multi Topic
#
#                                 disease_category disease sub_disease  \
# 0                                        Surgery     NaN         NaN
# 1                                        Surgery     NaN         NaN
# 2                                        Surgery     NaN         NaN
# 3                                        Surgery     NaN         NaN
# 4                                        Surgery     NaN         NaN
# 5                                        Surgery     NaN         NaN
# 6                                        Surgery     NaN         NaN
# 7                                        Surgery     NaN         NaN
# 8                                        Surgery     NaN         NaN
# 9                                        Surgery     NaN         NaN
# 10                                       Surgery     NaN         NaN
# 11                                       Surgery     NaN         NaN
# 12                                       Surgery     NaN         NaN
# 13                                 Endocrinology     NaN         NaN
# 14                                 Endocrinology     NaN         NaN
# 15                                 Endocrinology     NaN         NaN
# 16   Cardiology, Neurology, Oncology, Pediatrics     NaN         NaN
# 17                              Gastroenterology     NaN         NaN
# 18                                      Multiple     NaN         NaN
# 19                                      Multiple     NaN         NaN
# 20                                      Multiple     NaN         NaN
# 21                                      Multiple     NaN         NaN
# 22                                      Multiple     NaN         NaN
# 23                                      Multiple     NaN         NaN
# 24                                      Multiple     NaN         NaN
# 25                                      Multiple     NaN         NaN
# 26                                      Multiple     NaN         NaN
# 27                                      Multiple     NaN         NaN
# 28                                      Multiple     NaN         NaN
# 29                                      Multiple     NaN         NaN
# ..                                           ...     ...         ...
# 226                                     Multiple     NaN         NaN
# 227                                     Multiple     NaN         NaN
# 228                                     Multiple     NaN         NaN
# 229                                     Oncology     NaN         NaN
# 230                                     Oncology     NaN         NaN
# 231                                     Oncology     NaN         NaN
# 232                                    Oncology      NaN         NaN
# 233                                    Oncology      NaN         NaN
# 234                              Pain Management     NaN         NaN
# 235                                     Podiatry     NaN         NaN
# 236                                     Podiatry     NaN         NaN
# 237                                   Psychiatry     NaN         NaN
# 238                                      Surgery     NaN         NaN
# 239                                          NaN     NaN         NaN
# 240                                          NaN     NaN         NaN
# 241                                          NaN     NaN         NaN
# 242                                          NaN     NaN         NaN
# 243                                          NaN     NaN         NaN
# 244                                          NaN     NaN         NaN
# 245                                          NaN     NaN         NaN
# 246                                     Multiple     NaN         NaN
# 247                                     Multiple     NaN         NaN
# 248                                     Multiple     NaN         NaN
# 249                                     Multiple     NaN         NaN
# 250                                     Multiple     NaN         NaN
# 251                                     Multiple     NaN         NaN
# 252                                     Multiple     NaN         NaN
# 253                                     Multiple     NaN         NaN
# 254                                     Multiple     NaN         NaN
# 255                                     Multiple     NaN         NaN
#
#         pharma_firm
# 0    Paradigm Spine
# 1    Paradigm Spine
# 2    Paradigm Spine
# 3    Paradigm Spine
# 4    Paradigm Spine
# 5    Paradigm Spine
# 6    Paradigm Spine
# 7    Paradigm Spine
# 8    Paradigm Spine
# 9    Paradigm Spine
# 10   Paradigm Spine
# 11   Paradigm Spine
# 12   Paradigm Spine
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN
# ..              ...
# 226             NaN
# 227             NaN
# 228             NaN
# 229             NaN
# 230             NaN
# 231             NaN
# 232             NaN
# 233             NaN
# 234             NaN
# 235             NaN
# 236             NaN
# 237             NaN
# 238             NaN
# 239             NaN
# 240             NaN
# 241             NaN
# 242             NaN
# 243             NaN
# 244             NaN
# 245             NaN
# 246             NaN
# 247             NaN
# 248             NaN
# 249             NaN
# 250             NaN
# 251             NaN
# 252             NaN
# 253             NaN
# 254             NaN
# 255             NaN
#
# [256 rows x 8 columns]
